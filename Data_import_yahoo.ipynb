# %%
from forex_python.converter import CurrencyRates
from pandas_datareader import data
import datetime
from forex_python.converter import CurrencyRates
import matplotlib.pyplot as plt
import pandas as pd

# %%
c = CurrencyRates()
c.get_rates("USD")
# Out:
# {'GBP': 0.796651865,
#  'HKD': 7.7937833037,
#  'IDR': 14120.4973357016,
#  'ILS': 3.563410302,
#  'DKK': 6.628330373,
#  'INR': 68.4809058615,
#  'CHF': 0.9880994671,
#  'MXN': 18.9939609236,
#  'CZK': 22.6207815275,
#  'SGD': 1.3571936057,
#  'THB': 30.6651865009,
#  'HRK': 6.5697158082,
#  'EUR': 0.8880994671,
#  'MYR': 4.1355239787,
#  'NOK': 8.5546181172,
#  'CNY': 6.8761101243,
#  'BGN': 1.7369449378,
#  'PHP': 51.2113676732,
#  'PLN': 3.7698934281,
#  'ZAR': 14.1087921847,
#  'CAD': 1.3065719361,
#  'ISK': 125.8436944938,
#  'BRL': 3.8095026643,
#  'RON': 4.1959147425,
#  'NZD': 1.5019538188,
#  'TRY': 5.6070159858,
#  'JPY': 108.1438721137,
#  'RUB': 63.503374778,
#  'KRW': 1170.8969804618,
#  'USD': 1.0,
#  'AUD': 1.4260213144,
#  'HUF': 287.2202486679,
#  'SEK': 9.3761101243}

# %%
L = []
L2 = []
for i in range(1,30):
    date_obj = datetime.datetime(2019, 5, i, 18, 36, 28, 151012)
    L.append(date_obj)
    L2.append("5."+str(i))
    
date_obj = datetime.datetime(2019, 5, 23, 18, 36, 28, 151012)
#c.get_rates("USD", date_obj)

# %%
L1 = []
for i in L:
    L1.append(c.get_rate("USD","ZAR", i))

# %%
print(len(L1))
print(len(L2))
print(L2)
# Out:
# 29
# 29
# ['5.1', '5.2', '5.3', '5.4', '5.5', '5.6', '5.7', '5.8', '5.9', '5.10', '5.11', '5.12', '5.13', '5.14', '5.15', '5.16', '5.17', '5.18', '5.19', '5.20', '5.21', '5.22', '5.23', '5.24', '5.25', '5.26', '5.27', '5.28', '5.29']

# %%
fig, ax = plt.subplots(figsize=(16,9))

ax.plot(L2, L1, label='USD.ZAR')
#ax.plot(short_rolling_msft.index, short_rolling_msft, label='20 days rolling')
#ax.plot(long_rolling_msft.index, long_rolling_msft, label='100 days rolling')

ax.set_xlabel('Date')
ax.set_ylabel('Adjusted closing price ($)')
ax.legend()

# %%
c.get_rate('USD', 'INR',date_obj)
# Out:
# 69.947930694
